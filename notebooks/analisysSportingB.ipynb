# %% [markdown]
# # Tratamento e Análise dados Sporting Bet

# %%
#IMPORTANDO AS BIBLIOTECAS NECESSÃRIAS
import pandas as pd

# %%
# CARREGANDO DATA DO CSV
df_sb = pd.read_csv('dados/jogos_sportingbetBrasil.csv', on_bad_lines='skip') # PULA LINHAS MAL FORMATADAS

# %%
df_sb
# Out:
#                    Lyon              Brest              AO VIVO    2º T 78:14  \
# 0     Manchester United  Nottingham Forest              AO VIVO    2º T 75:37
# 1                  Lens               Nice              AO VIVO    2º T 75:47
# 2                  Roma          Cremonese              AO VIVO    2º T 72:37
# 3              Sporting              Braga              AO VIVO    1º T 17:27
# 4              Botafogo        Nova Iguaçu  Começando em 25 min          1.55
# 5          Athletico-PR             Azuriz  Começando em 40 min          1.22
# 6             Vila Nova    Grêmio Anápolis  Começando em 55 min          1.34
# 7    Bento Gonçalves-RS             Grêmio         Hoje / 20:00          9.75
# 8                Cuiabá        Sport Sinop         Hoje / 20:00          1.15
# 9             Fortaleza        Atlético-CE         Hoje / 20:45          1.13
# 10             Flamengo           Boavista         Hoje / 21:10          1.11
# 11  Barcelona de Ilhéus              Bahia         Hoje / 21:30          7.25
# 12             Mirassol          Palmeiras         Hoje / 21:35          4.75
# 13          Real Madrid           Valencia       Amanhã / 17:00  CRIAR APOSTA
# 14             Mirassol          Palmeiras         Hoje / 21:35          4.75
# 15                  NaN                NaN                  NaN           NaN
# 16              Guarani      RB Bragantino     04/02/2023 16:00          3.70
# 17          Ferroviária       São Bernardo     04/02/2023 16:00          2.40
# 18            Palmeiras             Santos     04/02/2023 18:30          1.78
# 19               Ituano         Água Santa     05/02/2023 11:00          2.10
# 20          Santo André          São Paulo     05/02/2023 16:00          3.70
# 21          Corinthians        Botafogo-SP     05/02/2023 18:30          1.55
# 22           Portuguesa   Inter de Limeira     05/02/2023 20:30          2.35
#
#        0    0.1          2.75  1.63  9.50   0,5  1.98  1.66
# 0   2.00   0.00  Aposte agora   NaN   NaN   NaN   NaN   NaN
# 1   0.00   1.00         11.50  3.50  1.40   1,5  1.87  1.73
# 2   0.00   2.00         18.50  7.25  1.12   2,5  1.58  2.10
# 3   1.00   0.00          1.29  4.60  9.00   2,5  1.46  2.37
# 4   3.80   6.25           2,5  2.05  1.68   NaN   NaN   NaN
# 5   5.25  12.00           2,5  1.78  1.90   NaN   NaN   NaN
# 6   4.20   8.25           2,5  2.10  1.65   NaN   NaN   NaN
# 7   4.50   1.31           2,5  1.98  1.73   NaN   NaN   NaN
# 8   6.50  14.50           2,5  1.71  2.00   NaN   NaN   NaN
# 9   7.00  17.00           2,5  1.65  2.10   NaN   NaN   NaN
# 10  9.50  21.00           3,5  2.30  1.53   NaN   NaN   NaN
# 11  3.90   1.41           2,5  2.25  1.57   NaN   NaN   NaN
# 12  3.40   1.77           2,5  2.15  1.61   NaN   NaN   NaN
# 13  1.39   5.00          7.75   2,5  1.60  2.20   NaN   NaN
# 14  3.40   1.77           2,5  2.15  1.61   NaN   NaN   NaN
# 15   NaN    NaN           NaN   NaN   NaN   NaN   NaN   NaN
# 16  3.20   2.05           1,5  1.49  2.40   NaN   NaN   NaN
# 17  3.00   3.00           2,5  2.45  1.49   NaN   NaN   NaN
# 18  3.50   4.40           2,5  2.00  1.70   NaN   NaN   NaN
# 19  3.10   3.60           1,5  1.49  2.40   NaN   NaN   NaN
# 20  3.40   1.98           2,5  2.25  1.55   NaN   NaN   NaN
# 21  3.80   6.25           2,5  2.05  1.66   NaN   NaN   NaN
# 22  3.00   3.10           1,5  1.53  2.30   NaN   NaN   NaN

# %% [markdown]
# ## Tratamento dos dados
# - Renomear as colunas
# - Eliminar colunas inuteis
# - Tratamento dos nulos
# - Ajuste dos tipos

# %%
# Renomeando as colunas
df_sb.columns = ['time_casa', 'time_visitante', 'aovivo', 'casa_ganha',
                 'empate', 'visitante_ganha', 'mais/menosQ', 'maisQ',
                 'menos_que', '', '', '']

# %%
df_sb.head(6)
# Out:
#            time_casa     time_visitante               aovivo  casa_ganha  \
# 0  Manchester United  Nottingham Forest              AO VIVO  2º T 75:37
# 1               Lens               Nice              AO VIVO  2º T 75:47
# 2               Roma          Cremonese              AO VIVO  2º T 72:37
# 3           Sporting              Braga              AO VIVO  1º T 17:27
# 4           Botafogo        Nova Iguaçu  Começando em 25 min        1.55
# 5       Athletico-PR             Azuriz  Começando em 40 min        1.22
#
#    empate  visitante_ganha   mais/menosQ maisQ  menos_que
# 0    2.00             0.00  Aposte agora   NaN        NaN  NaN   NaN   NaN
# 1    0.00             1.00         11.50  3.50       1.40  1,5  1.87  1.73
# 2    0.00             2.00         18.50  7.25       1.12  2,5  1.58  2.10
# 3    1.00             0.00          1.29  4.60       9.00  2,5  1.46  2.37
# 4    3.80             6.25           2,5  2.05       1.68  NaN   NaN   NaN
# 5    5.25            12.00           2,5  1.78       1.90  NaN   NaN   NaN

# %%
# Eliminando as colunas inuteis
df_sb.drop([''], axis='columns', inplace=True)

# %%
df_sb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time_casa        22 non-null     object
#  1   time_visitante   22 non-null     object
#  2   aovivo           22 non-null     object
#  3   casa_ganha       22 non-null     object
#  4   empate           22 non-null     float64
#  5   visitante_ganha  22 non-null     float64
#  6   mais/menosQ      22 non-null     object
#  7   maisQ            21 non-null     object
#  8   menos_que        21 non-null     float64
# dtypes: float64(3), object(6)
# memory usage: 1.7+ KB

# %%
# Tratando os nulos
# REMOVENDO TODAS AS COLUNAS QUE POSSUEM APENAS VALORES NULOS
df_semNulo = df_sb.dropna(how = 'all',axis='rows') # type: ignore

# %%
df_semNulo.head(6)
# Out:
#            time_casa     time_visitante               aovivo  casa_ganha  \
# 0  Manchester United  Nottingham Forest              AO VIVO  2º T 75:37
# 1               Lens               Nice              AO VIVO  2º T 75:47
# 2               Roma          Cremonese              AO VIVO  2º T 72:37
# 3           Sporting              Braga              AO VIVO  1º T 17:27
# 4           Botafogo        Nova Iguaçu  Começando em 25 min        1.55
# 5       Athletico-PR             Azuriz  Começando em 40 min        1.22
#
#    empate  visitante_ganha   mais/menosQ maisQ  menos_que
# 0    2.00             0.00  Aposte agora   NaN        NaN
# 1    0.00             1.00         11.50  3.50       1.40
# 2    0.00             2.00         18.50  7.25       1.12
# 3    1.00             0.00          1.29  4.60       9.00
# 4    3.80             6.25           2,5  2.05       1.68
# 5    5.25            12.00           2,5  1.78       1.90

# %%
df_semNulo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 0 to 22
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time_casa        22 non-null     object
#  1   time_visitante   22 non-null     object
#  2   aovivo           22 non-null     object
#  3   casa_ganha       22 non-null     object
#  4   empate           22 non-null     float64
#  5   visitante_ganha  22 non-null     float64
#  6   mais/menosQ      22 non-null     object
#  7   maisQ            21 non-null     object
#  8   menos_que        21 non-null     float64
# dtypes: float64(3), object(6)
# memory usage: 1.7+ KB

# %% [markdown]
# ## Analise dos dados
# - Buscando outliers
# - Verificando as distribuições
# - Buscar relações entre variaveis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.jointplot(data=df_semNulo)

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(data=df_semNulo)
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df_semNulo)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Existem alguns outliers, esses representam valores onde as odds foram muito altas (além do "normal")

# %%
# Por fim salvando o dataset
df_semNulo.to_csv('dados/dados tratados/jogos_sportingbet_tratado.csv')
